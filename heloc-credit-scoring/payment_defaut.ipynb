# %% [markdown]
# # Projet 3 : La prediction de remboursement de pret
# Dans ce projet, nous allons utiliser la methode P.R.E.D.I.C.T : Problème(Définir clairement le besoin métier à résoudre), Récupération(Collecter toutes les données pertinentes), Exploration(Comprendre et analyser les données disponibles), Data Cleaning (Préparer et nettoyer le dataset), Implémentation(Créer et entraîner le modèle), Contrôle(Évaluer rigoureusement la performance), Transformation(Déployer et intégrer la solution métier)

# %% [markdown]
# # I- Problème
#
# Le dataset HELOC a été publié par FICO dans le cadre d’un challenge d’IA explicable. Il contient des informations anonymisées sur des demandes de lignes de crédit (de 5 000 à 150 000 $), avec l’objectif de prédire si un client remboursera son crédit dans les 2 ans. Ce projet vous permettra de démontrer votre maîtrise de la modélisation du risque de crédit, un atout majeur pour votre objectif de devenir expert en risque et crédit.

# %% [markdown]
# # II- Récupération

# %%
# Importation des librairies nécessaires au projet

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
